# %% [markdown]
# **Kaggle 競賽網址**

# %% [markdown]
# https://www.kaggle.com/c/competitive-data-science-predict-future-sales/overview

# %% [markdown]
# **source**

# %% [markdown]
# https://www.kaggle.com/abdalazez/predict-future-sales-2020#1.-Data-Cleaning

# %% [markdown]
# https://www.kaggle.com/benjaminhthomas/modern-forecasting#More-Complex-Forecasting-(Competition-Entry)
